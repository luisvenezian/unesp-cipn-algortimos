# %%
import matplotlib.pyplot as plt

# Dados para cada algoritmo
subida_da_colina = [
    [0.11484204015784523, 4.999999999988347e-05],
    [0.7674698803165547, 1.8999999999991246e-05],
    [0.7155929860347975, 5.9000000000253294e-05],
    [0.05599858657912253, 3.900000000012227e-05],
    [0.8586916124223736, 2.299999999966218e-05],
    [0.3436178683626216, 4.900000000063187e-05],
    [0.9191182350856234, 3.799999999998249e-05],
    [0.7603501867609614, 9.000000000369823e-06],
    [0.6113175767770078, 6.199999999978445e-05],
    [0.7155929860347975, 3.799999999998249e-05]
]

recozimento_simulado = [
    [0.7598172388096363, 2.899999999961267e-05],
    [0.8484247582158664, 2.19999999995224e-05],
    [0.8250028264696213, 6.4000000000064e-05],
    [0.8064859689558187, 3.9999999996709334e-06],
    [0.9298393094002799, 1.7999999999851468e-05],
    [0.002515727544359896, 8.00000000005241e-05],
    [0.9954370923376367, 8.000000000230045e-06],
    [0.9005516742334123, 5.999999999950489e-06],
    [0.7307317391598236, 7.200000000029405e-05],
    [0.9129536221964023, 4.1000000000401826e-05]
]

algoritmo_genetico = [
    [0.8953047561166383, 0.0017549999999999996],
    [0.9338317643535151, 0.0015579999999999969],
    [1.0, 0.0007370000000000015],
    [0.7837609388290764, 0.0016170000000000004],
    [1.0, 0.0003419999999999951],
    [0.9338317643535151, 0.0015890000000000001],
    [0.9338317643535151, 0.0015389999999999987],
    [0.9881915635313728, 0.0015410000000000007],
    [0.6718356645157781, 0.0015889999999999932],
    [1.0, 0.0005890000000000062]
]

# Extrair valores de f(x) e tempos de execução para cada algoritmo
subida_da_colina_fx, subida_da_colina_tempo = zip(*subida_da_colina)
recozimento_simulado_fx, recozimento_simulado_tempo = zip(*recozimento_simulado)
algoritmo_genetico_fx, algoritmo_genetico_tempo = zip(*algoritmo_genetico)

# Plotar os dados
plt.figure(figsize=(10, 6))
plt.scatter(subida_da_colina_tempo, subida_da_colina_fx, label='Subida da Colina')
plt.scatter(recozimento_simulado_tempo, recozimento_simulado_fx, label='Recozimento Simulado')
plt.scatter(algoritmo_genetico_tempo, algoritmo_genetico_fx, label='Algoritmo Genético')
plt.xlabel('Tempo de Execução do Algoritmo')
plt.ylabel('f(x)')
plt.title('Desempenho dos Algoritmos')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Dados para cada algoritmo
subida_da_colina = [
    [0.11484204015784523, 4.999999999988347e-05],
    [0.7674698803165547, 1.8999999999991246e-05],
    [0.7155929860347975, 5.9000000000253294e-05],
    [0.05599858657912253, 3.900000000012227e-05],
    [0.8586916124223736, 2.299999999966218e-05],
    [0.3436178683626216, 4.900000000063187e-05],
    [0.9191182350856234, 3.799999999998249e-05],
    [0.7603501867609614, 9.000000000369823e-06],
    [0.6113175767770078, 6.199999999978445e-05],
    [0.7155929860347975, 3.799999999998249e-05]
]

recozimento_simulado = [
    [0.7598172388096363, 2.899999999961267e-05],
    [0.8484247582158664, 2.19999999995224e-05],
    [0.8250028264696213, 6.4000000000064e-05],
    [0.8064859689558187, 3.9999999996709334e-06],
    [0.9298393094002799, 1.7999999999851468e-05],
    [0.002515727544359896, 8.00000000005241e-05],
    [0.9954370923376367, 8.000000000230045e-06],
    [0.9005516742334123, 5.999999999950489e-06],
    [0.7307317391598236, 7.200000000029405e-05],
    [0.9129536221964023, 4.1000000000401826e-05]
]

algoritmo_genetico = [
    [0.981603959687526, 0.0025099999999999983], 
    [1.0, 0.0023060000000000025], 
    [0.9325005544769892, 0.0021190000000000098], 
    [0.999258312938979, 0.0020869999999999916], 
    [0.9338317643535151, 0.0020850000000000035], 
    [0.9338317643535151, 0.00214099999999999], 
    [0.999258312938979, 0.00203600000000001], 
    [0.9933424072569104, 0.0019810000000000105], 
    [0.7604568383618461, 0.0019249999999999962], 
    [0.9736054988708979, 0.0019539999999999974]
]

# Extrair valores de f(x) e tempos de execução para cada algoritmo
subida_da_colina_fx, subida_da_colina_tempo = zip(*subida_da_colina)
recozimento_simulado_fx, recozimento_simulado_tempo = zip(*recozimento_simulado)
algoritmo_genetico_fx, algoritmo_genetico_tempo = zip(*algoritmo_genetico)

# Plotar os dados
plt.figure(figsize=(10, 6))
plt.scatter(subida_da_colina_tempo, subida_da_colina_fx, label='Subida da Colina')
plt.scatter(recozimento_simulado_tempo, recozimento_simulado_fx, label='Recozimento Simulado')
plt.scatter(algoritmo_genetico_tempo, algoritmo_genetico_fx, label='Algoritmo Genético')
plt.xlabel('Tempo de Execução do Algoritmo')
plt.ylabel('f(x)')
plt.title('Desempenho dos Algoritmos')
plt.legend()
plt.grid(True)

# show in high quality plot
# plt.show()
plt.savefig('filename.png', dpi=300)
